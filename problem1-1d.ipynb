# %%
# %matplotlib inline

# %%
import fipy as fp

# %%
from fipy import numerix as nmx

# %%
N = 20
mesh = fp.Grid1D(nx=N)

# %%
C = fp.CellVariable(mesh=mesh, name="C", hasOld=True)

# %%
Calpha = 0.05
Cbeta = 0.95
Cm = (Calpha + Cbeta) / 2.
A = 2.0
B = A / (Calpha - Cm)**2
D = Dalpha = Dbeta = 2 / (Cbeta - Calpha)
kappa = 2.0

# %%
f0 = -(A/2)*(C - Cm)**2 + (B/4)*(C - Cm)**4 + (Calpha/4)*(C - Calpha)**4 + (Cbeta/4)*(C - Cbeta)**4

# %%
f = f0 + (kappa/2.)*(C.grad.mag)**2
f.name = "f"

# %%
Cf = C.arithmeticFaceValue
eq = (fp.TransientTerm(coeff=1.)
      == fp.DiffusionTerm(coeff=D*(-A + 3*B*(Cf - Cm)**2 + 3*Calpha*(Cf - Calpha)**2 + 3*Cbeta*(Cf - Cbeta)**2))
      - fp.DiffusionTerm(coeff=(D,kappa)))

# %%
viewer = fp.MatplotlibViewer(vars=C)

# %%
C.value = 1 * (mesh.x < 10)

# %%
dt = 0.01
elapsed = 0.
saved = elapsed
duration = 10000.
step = 0

# %%
import os

# %%
os.mkdir("1-1d")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-20e0b6699e2b> in <module>()
# ----> 1 os.mkdir("1-1d")
#
# OSError: [Errno 17] File exists: '1-1d'

# %%
fp.tools.dump.write(mesh, filename="1-1d/mesh.dmp")

# %%
fp.TSVViewer(vars=C).plot(filename="1-1d/{step}.gz".format(step=0))

# %%
with open("1-1d/stats.txt", 'w') as stats:
    stats.write("\t".join(["step", "t", "dt", "Cmin", "Cmax", "f"]) + "\n")

# %%
while elapsed < duration:
    C.updateOld()
    for sweep in range(6):
        res = eq.sweep(C, dt=dt) #, solver=fp.LinearLUSolver())
    if res < 0.1:
        step += 1
        elapsed += dt
        dt *= 1.1
        viewer.plot()
        with open("1-1d/stats.txt", 'a') as stats:
            stats.write("\t".join([str(it) for it in [step, elapsed, dt, min(C), max(C), 
                                                      f.cellVolumeAverage * mesh.cellVolumes.sum()]]) + "\n")
    else:
        dt *= 0.8
        C.value = C.old.value
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-34879f3e367d> in <module>()
#       2     C.updateOld()
#       3     for sweep in range(6):
# ----> 4         res = eq.sweep(C, dt=dt) #, solver=fp.LinearLUSolver())
#       5     if res < 0.1:
#       6         step += 1
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/term.pyc in sweep(self, var, solver, boundaryConditions, dt, underRelaxation, residualFn, cacheResidual, cacheError)
#     221
#     222         """
# --> 223         solver = self._prepareLinearSystem(var=var, solver=solver, boundaryConditions=boundaryConditions, dt=dt)
#     224         solver._applyUnderRelaxation(underRelaxation=underRelaxation)
#     225         residual = solver._calcResidual(residualFn=residualFn)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/term.pyc in _prepareLinearSystem(self, var, solver, boundaryConditions, dt)
#     155                                                            transientGeomCoeff=self._getTransientGeomCoeff(var),
#     156                                                            diffusionGeomCoeff=self._getDiffusionGeomCoeff(var),
# --> 157                                                            buildExplicitIfOther=self._buildExplcitIfOther)
#     158
#     159         self._buildCache(matrix, RHSvector)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/unaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      97                                                        dt=dt,
#      98                                                        transientGeomCoeff=transientGeomCoeff,
# ---> 99                                                        diffusionGeomCoeff=diffusionGeomCoeff)
#     100         elif buildExplicitIfOther:
#     101             _, matrix, RHSvector = self._buildMatrix(self.var,
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/abstractDiffusionTerm.pyc in _buildMatrix(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff)
#     316         """
#     317
# --> 318         var, L, b = self.__higherOrderbuildMatrix(var, SparseMatrix, boundaryConditions=boundaryConditions, dt=dt, transientGeomCoeff=transientGeomCoeff, diffusionGeomCoeff=diffusionGeomCoeff)
#     319         mesh = var.mesh
#     320
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/abstractDiffusionTerm.pyc in __higherOrderbuildMatrix(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff)
#     438
#     439             L, b = self.__doBCs(SparseMatrix, higherOrderBCs, N, M, self.coeffDict,
# --> 440                                self.__getCoefficientMatrix(SparseMatrix, var, self.coeffDict['cell 1 diag']), numerix.zeros(len(var.ravel()),'d'))
#     441
#     442             if hasattr(self, 'anisotropySource'):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/abstractDiffusionTerm.pyc in __getCoefficientMatrix(self, SparseMatrix, var, coeff)
#     222
#     223         coefficientMatrix = SparseMatrix(mesh=mesh, bandwidth = mesh._maxFacesPerCell + 1)
# --> 224         interiorCoeff = numerix.take(coeff, interiorFaces, axis=-1).ravel()
#     225         coefficientMatrix.addAt(interiorCoeff, id1.ravel(), id1.swapaxes(0,1).ravel())
#     226         coefficientMatrix.addAt(-interiorCoeff, id1.ravel(), id2.swapaxes(0,1).ravel())
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/tools/numerix.pyc in take(a, indices, axis, fill_value)
#     618
#     619     if _isPhysical(a):
# --> 620         taken = a.take(indices, axis=axis)
#     621     elif type(indices) is type(MA.array((0))):
#     622         ## Replaces `MA.take`. `MA.take` does not always work when
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in take(self, ids, axis)
#    1432
#    1433     def take(self, ids, axis=0):
# -> 1434         return numerix.take(self.value, ids, axis)
#    1435
#    1436     def allclose(self, other, rtol=1.e-5, atol=1.e-8):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/unaryOperatorVariable.pyc in _calcValue_(self)
#      65     class unOp(operatorClass):
#      66         def _calcValue_(self):
# ---> 67             return self.op(self.var[0].value)
#      68
#      69         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      70         def _calcValue(self):
#      71             if not self.canInline:
# ---> 72                 return self._calcValue_()
#      73             else:
#      74                 from fipy.tools import inline
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/unaryOperatorVariable.pyc in _calcValue_(self)
#      65     class unOp(operatorClass):
#      66         def _calcValue_(self):
# ---> 67             return self.op(self.var[0].value)
#      68
#      69         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      70         def _calcValue(self):
#      71             if not self.canInline:
# ---> 72                 return self._calcValue_()
#      73             else:
#      74                 from fipy.tools import inline
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/unaryOperatorVariable.pyc in _calcValue_(self)
#      65     class unOp(operatorClass):
#      66         def _calcValue_(self):
# ---> 67             return self.op(self.var[0].value)
#      68
#      69         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/binaryOperatorVariable.pyc in _calcValue_(self)
#      79                 val1 = self.var[1]
#      80
# ---> 81             return self.op(self.var[0].value, val1)
#      82
#      83         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/binaryOperatorVariable.pyc in _calcValue_(self)
#      79                 val1 = self.var[1]
#      80
# ---> 81             return self.op(self.var[0].value, val1)
#      82
#      83         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/unaryOperatorVariable.pyc in _calcValue_(self)
#      65     class unOp(operatorClass):
#      66         def _calcValue_(self):
# ---> 67             return self.op(self.var[0].value)
#      68
#      69         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/binaryOperatorVariable.pyc in _calcValue_(self)
#      79                 val1 = self.var[1]
#      80
# ---> 81             return self.op(self.var[0].value, val1)
#      82
#      83         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/binaryOperatorVariable.pyc in _calcValue_(self)
#      79                 val1 = self.var[1]
#      80
# ---> 81             return self.op(self.var[0].value, val1)
#      82
#      83         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      76                     return self._execInline(comment=self.comment)
#      77                 else:
# ---> 78                     return self._calcValue_()
#      79
#      80         def _calcValue_(self):
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/binaryOperatorVariable.pyc in _calcValue_(self)
#      79                 val1 = self.var[1]
#      80
# ---> 81             return self.op(self.var[0].value, val1)
#      82
#      83         @property
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/variable.pyc in _getValue(self)
#     510
#     511         if self.stale or not self._isCached() or self._value is None:
# --> 512             value = self._calcValue()
#     513             if self._isCached():
#     514                 self._setValueInternal(value=value)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/variables/operatorVariable.pyc in _calcValue(self)
#      72                 return self._calcValue_()
#      73             else:
# ---> 74                 from fipy.tools import inline
#      75                 if inline.doInline:
#      76                     return self._execInline(comment=self.comment)
#
# KeyboardInterrupt:
