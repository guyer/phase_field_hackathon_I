# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import fipy as fp
from fipy.tools import numerix as nmx

# %% [markdown]
# # periodic

# %%
mesh = fp.dump.read("1a/mesh.dmp")

# %%
C = fp.CellVariable(mesh=mesh, value=0., name="C")

# %%
viewer = fp.MatplotlibViewer(vars=C)

# %%
x, y, value = nmx.loadtxt(fname="1a/0.gz", skiprows=2, unpack=True)

# %%
C.value = value

# %%
viewer.plot()

# %%
x, y, value = nmx.loadtxt(fname="1a/118.gz", skiprows=2, unpack=True)
C.value = value
viewer.plot()

# %%
x, y, value = nmx.loadtxt(fname="1a/134.gz", skiprows=2, unpack=True)
C.value = value
viewer.plot()

# %%
x, y, value = nmx.loadtxt(fname="1a/3530.gz", skiprows=2, unpack=True)
C.value = value
viewer.plot()

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1a/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot?

# %%
plt.plot(t, f)

# %%
plt.plot(t, dt)

# %%
plt.plot(t, Cmin, t, Cmax)

# %% [markdown]
# # sphere

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1d/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t, f)

# %%
plt.plot(t, dt)

# %%
plt.plot(t, step)

# %%
sphere = fp.dump.read("1d/mesh.dmp")

# %%
Csphere = fp.CellVariable(mesh=sphere, value=0., name="C")

# %%
sphere_viewer = fp.Viewer(vars=Csphere)

# %%
x, y, z, value = nmx.loadtxt(fname="1d/186.gz", skiprows=2, unpack=True)
Csphere.value = value
sphere_viewer.plot()

# %%
Csphere.value = sphere.z.faceGrad.divergence
sphere_viewer.plot()

# %% [markdown]
# # sphere exp

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1d-exp/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t[:600], f[:600])

# %%
plt.plot(t, dt)

# %%
print t[602]
# Out:
# 278.037953429

# %%
print dt[602] / t[602]**(2./3)
# Out:
# 0.0650994994763

# %%
print 0.0651 * (t[602] + dt[602])**(2./3)
# Out:
# 2.79162589875

# %%
plt.plot(step, nmx.log10(dt))

# %%
sphere_exp = fp.dump.read("1d-exp/mesh.dmp")

# %%
Csphere_exp = fp.CellVariable(mesh=sphere_exp, value=0., name="C")

# %%
sphere_exp_viewer = fp.Viewer(vars=Csphere_exp)

# %%
x, y, z, value = nmx.loadtxt(fname="1d-exp/700.gz", skiprows=2, unpack=True)
Csphere_exp.value = value
sphere_exp_viewer.plot()

# %%
0.21 * 0.035**(2./3)
# Out:
# 0.022469737091866674

# %% [markdown]
# # sphere t**(2/3)

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1d-exp-restart/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t[:119], f[:119])

# %%
print step[118]
# Out:
# 722.0

# %%
plt.plot(t, dt)

# %%
sphere_pwr = fp.dump.read("1d-exp-restart/mesh.dmp")

# %%
Csphere_pwr = fp.CellVariable(mesh=sphere_pwr, value=0., name="C")

# %%
sphere_pwr_viewer = fp.Viewer(vars=Csphere_pwr)

# %%
x, y, z, value = nmx.loadtxt(fname="1d-exp-restart/701.gz", skiprows=2, unpack=True)
Csphere_pwr.value = value
sphere_pwr_viewer.plot()

# %% [markdown]
# # 1d

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1-1d/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t, f)

# %%
plt.plot(t, dt)

# %% [markdown]
# # 2D in 3D

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1b-3d/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t, f)

# %%
plt.plot(t, dt)

# %%
mesh2Din3D = fp.dump.read("1b-3d/mesh.dmp")

# %%
C2Din3D = fp.CellVariable(mesh=mesh2Din3D, value=0., name="C")

# %%
C2Din3D_viewer = fp.Viewer(vars=C2Din3D)

# %%
x, y, z, value = nmx.loadtxt(fname="1b-3d/852.gz", skiprows=2, unpack=True)
C2Din3D.value = value
C2Din3D_viewer.plot()

# %% [markdown]
# # 2D coarse - 5

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1a-coarse/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t,f)

# %%
coarse = fp.dump.read("1a-coarse/mesh.dmp")

# %%
Ccoarse = fp.CellVariable(mesh=coarse, value=0., name="C")

# %%
Ccoarse_viewer = fp.MatplotlibViewer(vars=Ccoarse)

# %%
x, y, value = nmx.loadtxt(fname="1a-coarse/153.gz", skiprows=2, unpack=True)
Ccoarse.value = value
Ccoarse_viewer.plot()

# %% [markdown]
# # 2D coarse - 3

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1a-coarse/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t,f)

# %%
coarse = fp.dump.read("1a-coarse/mesh.dmp")

# %%
Ccoarse = fp.CellVariable(mesh=coarse, value=0., name="C")

# %%
Ccoarse_viewer = fp.MatplotlibViewer(vars=Ccoarse)

# %%
x, y, value = nmx.loadtxt(fname="1a-coarse/", skiprows=2, unpack=True)
Ccoarse.value = value
Ccoarse_viewer.plot()

# %% [markdown]
# # 2D coarse - 2

# %%
step, t, dt, Cmin, Cmax, f, err = nmx.loadtxt(fname="1a-coarse-2/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t,f)

# %%
plt.plot(t[:50], err[:50])

# %%
coarse = fp.dump.read("1a-coarse-2/mesh.dmp")

# %%
Ccoarse = fp.CellVariable(mesh=coarse, value=0., name="C")

# %%
Ccoarse_viewer = fp.MatplotlibViewer(vars=Ccoarse)

# %%
x, y, value = nmx.loadtxt(fname="1a-coarse-2/50.gz", skiprows=2, unpack=True)
Ccoarse.value = value
Ccoarse_viewer.plot()

# %% [markdown]
# # 1a retry

# %%
step, t, dt, Cmin, Cmax, f = nmx.loadtxt(fname="1a-retry/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t,f)

# %%
plt.plot(t, nmx.log(dt))

# %%
plt.plot(t,step)

# %%
mesh = fp.dump.read("1a-retry/mesh.dmp")

# %%
C = fp.CellVariable(mesh=mesh, value=0., name="C")

# %%
viewer = fp.MatplotlibViewer(vars=C)

# %%
x, y, value = nmx.loadtxt(fname="1a-retry/113.gz", skiprows=2, unpack=True)
C.value = value
viewer.plot()

# %% [markdown]
# # 1a course 1

# %%
step, t, dt, Cmin, Cmax, f, err = nmx.loadtxt(fname="1a-coarse-1/stats.txt", skiprows=1, unpack=True)

# %%
plt.plot(t,f)

# %%
plt.plot(t, step)

# %%
plt.plot(t,nmx.log10(err))

# %%
plt.plot(t, dt) #nmx.log10(dt))

# %%
mesh = fp.dump.read("1a-coarse-1/mesh.dmp")

# %%
C = fp.CellVariable(mesh=mesh, value=0., name="C")

# %%
viewer = fp.MatplotlibViewer(vars=C)

# %%
x, y, value = nmx.loadtxt(fname="1a-coarse-1/695.gz", skiprows=2, unpack=True)
C.value = value
viewer.plot()
