# %%
# %matplotlib inline

# %%
import fipy as fp

# %%
from fipy import numerix as nmx

# %% [markdown]
# # initialize

# %%
N = 200
mesh = fp.PeriodicGrid2D(nx=N, ny=N)

# %% [markdown]
# # restart

# %%
mesh = fp.dump.read("mesh.dmp")

# %%
Calpha = fp.Variable(0.05, name=r"$C_\alpha$")
Cbeta = fp.Variable(0.95, name=r"$C_\beta$")
Cm = (Calpha + Cbeta) / 2.
Cm.name = "$C_m$"
A = fp.Variable(2.0, name="A")
B = A / (Calpha - Cm)**2
B.name = "B"
gamma = 2. / (Cbeta - Calpha)**2
gamma.name = r"$\gamma$"
beta = fp.Variable(1.0, name=r"$\beta$")
Dalpha = gamma / beta**2
Dalpha.name = r"$D_\alpha$"
Dbeta = gamma / beta**2
Dbeta.name = r"$D_\beta$"
epsilonij = fp.Variable(3.0, name=r"$\epsilon_{ij}$")
kappai = fp.Variable(2.0, name=r"$\kappa_i$")
kappaC = fp.Variable(2.0, name=r"$\kappa_C$")
D = fp.Variable(1.0, name="D")
Li = fp.Variable(1.0, name="$L_i$")

# %%
C = fp.CellVariable(mesh=mesh, name="C", hasOld=True)

# %%
eta = [fp.CellVariable(mesh=mesh, name=r"$\eta_{i}$".format(i=i+1), hasOld=True) for i in range(10)]

# %%
f1 = -(A/2)*(C - Cm)**2 + (B/4)*(C - Cm)**4 + (Dalpha/4)*(C - Calpha)**4 + (Dbeta/4)*(C - Cbeta)**4
f1.name = "$f_1$"

f2 = []
for i, etai in enumerate(eta):
    f2i = -(gamma/2)*(C - Calpha)**2 * etai**2 + (beta/4)*etai**4
    f2i.name = "$f_{{2{i}}}$".format(i=i+1)
    f2.append(f2i)

f3 = []
for i, etai in enumerate(eta):
    f3i = []
    for j, etaj in enumerate(eta):
        if etaj is not etai:
            f3ij = (epsilonij/2) * etai**2 * etaj**2 
            f3ij.name = "$f_{{3{i}{j}}}$".format(i=i+1, j=j+1)
        else:
            f3ij = None
        f3i.append(f3ij)
    f3.append(f3i)
    
f0 = f1
for f2i in f2:
    f0 += f2i
for f3i in f3:
    for f3ij in f3i:
        if f3ij is not None:
            f0 += f3ij
f0.name = "$f_0$"

# %%
f = f0 + (kappaC/2.)*(C.grad.mag)**2
for etai in eta:
    f += (kappai/2.)*(etai.grad.mag)**2
f.name = "f"

# %%
Cf = C.arithmeticFaceValue
Cf.name = "C"
eqC = (fp.TransientTerm(coeff=1., var=C)
       == fp.DiffusionTerm(coeff=D*(-A + 3*B*(Cf - Cm)**2 
                                    + 3*Dalpha*(Cf - Calpha)**2 
                                    + 3*Dbeta*(Cf - Cbeta)**2), var=C)
       - fp.DiffusionTerm(coeff=(D,kappaC), var=C))
for etai in eta:
    eqC += fp.DiffusionTerm(coeff=D*gamma*etai**2, var=C)
    eqC += fp.DiffusionTerm(coeff=2*D*gamma*(Cf-Calpha), var=etai)
#    eqC += (fp.ConvectionTerm(coeff=2*D*gamma*etai.faceGrad, var=C) 
#            - (2*D*gamma*Calpha*etai.faceGrad).divergence)

# %%
eq_eta = []
for etai in eta:
    eqi = (fp.TransientTerm(coeff=1., var=etai)
           == fp.ImplicitSourceTerm(coeff=Li*gamma*(C-Calpha)*etai, var=C)
           - fp.ImplicitSourceTerm(coeff=Li*gamma*(C-Calpha)*Calpha, var=etai)
           - fp.ImplicitSourceTerm(coeff=Li*beta*etai**2, var=etai)
           + fp.DiffusionTerm(coeff=Li*kappai, var=etai))
    for etaj in eta:
        if etaj is not etai:
            eqi += fp.ImplicitSourceTerm(coeff=Li*epsilonij*etaj**2, var=etai)
    eq_eta.append(eqi)

# %%
eq_eta = []
for etai in eta:
    eqi = (fp.TransientTerm(coeff=1., var=etai)
           == fp.ImplicitSourceTerm(coeff=Li*gamma*(C-Calpha)**2, var=etai)
           - fp.ImplicitSourceTerm(coeff=Li*beta*etai**2, var=etai)
           + fp.DiffusionTerm(coeff=Li*kappai, var=etai))
    for etaj in eta:
        if etaj is not etai:
            eqi += fp.ImplicitSourceTerm(coeff=Li*epsilonij*etaj**2, var=etai)
    eq_eta.append(eqi)

# %%
eq = eqC
for eq_etai in eq_eta:
    eq &= eq_etai

# %%
phase = 0.
for i, etai in enumerate(eta):
    phase += (i+1 + etai) * (etai > 0.01)
phase.name = "$\eta$"

# %%
print min(eta[0]), min(eta[0]), eta[0].cellVolumeAverage
# Out:
# 0.0 0.0 0.0

# %%
viewer = fp.MatplotlibViewer(vars=phase)

# %%
viewer.plot()

# %% [markdown]
# # initialize with noise

# %%
epsilon = 0.01
q = [[0.1*nmx.sqrt(2.)], [0.1*nmx.sqrt(3.)]]
C.value = 0.45 + epsilon * nmx.cos(nmx.dot(q, mesh.cellCenters))

# %%
epsilon = [0.979285, 0.219812, 0.837709, 0.695603, 0.225115, 
           0.389266, 0.585953, 0.614471, 0.918038, 0.518569]

# %%
for i, (etai, epsiloni) in enumerate(zip(eta, epsilon)):
    qi = [[0.01*nmx.sqrt(23 + i + 1)], [0.01*nmx.sqrt(149 + i + 1)]]
    etai.value = 0.01 * epsiloni * nmx.cos(nmx.dot(qi, mesh.cellCenters))**2

# %% [markdown]
# # restart

# %%
values = nmx.loadtxt(fname="400.gz", skiprows=1, unpack=True)
x, y = values[0:2]
Cval = values[2]
etaval = values[3:]

# %%
C.value = Cval
for etai, etavali in zip(eta, etaval):
    etai.value = etavali

# %% [markdown]
# # run

# %%
fp.MatplotlibViewer(vars=C).plot()

# %%
fp.MatplotlibViewer(vars=eta[0]).plot()

# %%
dt = 0.01
elapsed = 4.0 # 0.
saved = elapsed
duration = 10000.
step = 400 # 0

# %%
fp.tools.dump.write(mesh, filename="mesh.dmp")

# %%
fp.TSVViewer(vars=[C] + eta).plot(filename="{step}.gz".format(step=0))

# %%
with open("stats.txt", 'w') as stats:
    stats.write("\t".join(["step", "t", "dt", "Cmin", "Cmax", "f"]) + "\n")

# %%
viewerC = fp.MatplotlibViewer(vars=C)

# %%
while elapsed < duration:
    C.updateOld()
    for etai in eta:
        etai.updateOld()
    for sweep in range(6):
#        res = eq.sweep(dt=dt)
        res = [eqC.sweep(C, dt=dt)] #, solver=fp.LinearLUSolver())
        res = res + [eq_etai.sweep(etai, dt=dt) for (eq_etai, etai) in zip(eq_eta, eta)]
    if max(res) < 0.1:
        step += 1
        elapsed += dt
        dt *= 1.1
        # viewer.plot()
        if elapsed - saved > 0.1:
            fp.TSVViewer(vars=[C] + eta).plot(filename="{step}.gz".format(step=step))
            viewer.plot()
            saved = elapsed
        with open("stats.txt", 'a') as stats:
            stats.write("\t".join([str(it) for it in [step, elapsed, dt, min(C), max(C), 
                                                      f.cellVolumeAverage * mesh.cellVolumes.sum()]]) + "\n")
    else:
        dt *= 0.8
        C.value = C.old.value
    print dt
# Out:
# 0.0143915655178
# 0.0115132524142
# 0.0126645776557
# 0.0101316621245
# 0.00810532969962
# 0.00891586266958
# 0.00713269013567
# 0.00784595914923
# 0.00627676731939
# 0.00690444405132
# 0.00552355524106
# 0.00607591076517
# 0.00486072861213
# 0.00388858288971
# 0.00427744117868
# 0.00342195294294
# 0.00376414823724
# 0.00301131858979
# 0.00331245044877
# 0.00264996035901
# 0.00291495639491
# 0.00233196511593
# 0.00186557209275
# 0.00205212930202
# 0.00164170344162
# 0.00180587378578
# 0.00198646116436
# 0.00158916893148
# 0.00127133514519
# 0.00139846865971
# 0.00153831552568
# 0.00123065242054
# 0.000984521936433
# 0.00108297413008
# 0.00119127154308
# 0.000953017234467
# 0.00104831895791
# 0.000838655166331
# 0.000922520682964
# 0.000738016546371
# 0.000811818201009
# 0.000649454560807
# 0.000714400016888
# 0.00057152001351
# 0.000628672014861
# 0.000502937611889
# 0.000553231373078
# 0.000442585098462
# 0.000486843608308
# 0.000389474886647
# 0.000428422375311
# 0.000471264612843
# 0.000377011690274
# 0.000414712859301
# 0.000331770287441
# 0.000364947316185
# 0.000291957852948
# 0.000321153638243
# 0.000256922910594
# 0.000282615201654
# 0.000310876721819
# 0.000248701377455
# 0.000273571515201
# 0.000218857212161
# 0.000240742933377
# 0.000192594346701
# 0.000211853781372
# 0.000233039159509
# 0.000186431327607
# 0.000205074460368
# 0.000164059568294
# 0.000180465525124
# 0.000144372420099
# 0.000158809662109
# 0.00017469062832
# 0.000139752502656
# 0.000153727752921
# 0.000122982202337
# 0.000135280422571
# 0.000148808464828
# 0.000119046771862
# 0.000130951449048
# 0.000104761159239
# 0.000115237275163
# 0.000126761002679
# 0.000101408802143
# 0.000111549682357
# 8.9239745886e-05
# 9.81637204746e-05
# 0.000107980092522
# 8.63840740176e-05
# 9.50224814194e-05
# 7.60179851355e-05
# 8.3619783649e-05
# 9.19817620139e-05
# 7.35854096112e-05
# 8.09439505723e-05
# 6.47551604578e-05
# 1.25847006778e-06
# 1.00677605422e-06
# 1.10745365964e-06
# 1.21819902561e-06
# 9.74559220487e-07
# 1.07201514254e-06
# 1.17921665679e-06
# 9.43373325432e-07
# 1.03771065797e-06
# 1.14148172377e-06
# 9.13185379018e-07
# 1.00450391692e-06
# 1.10495430861e-06
# 8.83963446889e-07
# 9.72359791578e-07
# 1.06959577074e-06
# 8.55676616589e-07
# 9.41244278248e-07
# 1.03536870607e-06
# 8.28294964858e-07
# 9.11124461344e-07
# 1.00223690748e-06
# 8.01789525982e-07
# 8.81968478581e-07
# 9.70165326439e-07
# 7.76132261151e-07
# 8.53745487266e-07
# 9.39120035993e-07
# 7.51296028794e-07
# 8.26425631674e-07
# 9.09068194841e-07
# 7.27254555873e-07
# 7.9998001146e-07
# 8.79978012606e-07
# 7.03982410085e-07
# 7.74380651093e-07
# 8.51818716203e-07
# 6.81454972962e-07
# 7.49600470258e-07
# 8.24560517284e-07
# 6.59648413827e-07
# 7.2561325521e-07
# 7.98174580731e-07
# 6.38539664585e-07
# 7.02393631043e-07
# 7.72632994148e-07
# 6.18106395318e-07
# 6.7991703485e-07
# 7.47908738335e-07
# 5.98326990668e-07
# 6.58159689735e-07
# 7.23975658708e-07
# 5.79180526967e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b739df6ce42f> in <module>()
#       5     for sweep in range(6):
#       6 #        res = eq.sweep(dt=dt)
# ----> 7         res = [eqC.sweep(C, dt=dt)] #, solver=fp.LinearLUSolver())
#       8         res = res + [eq_etai.sweep(etai, dt=dt) for (eq_etai, etai) in zip(eq_eta, eta)]
#       9     if max(res) < 0.1:
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/term.pyc in sweep(self, var, solver, boundaryConditions, dt, underRelaxation, residualFn, cacheResidual, cacheError)
#     221
#     222         """
# --> 223         solver = self._prepareLinearSystem(var=var, solver=solver, boundaryConditions=boundaryConditions, dt=dt)
#     224         solver._applyUnderRelaxation(underRelaxation=underRelaxation)
#     225         residual = solver._calcResidual(residualFn=residualFn)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/term.pyc in _prepareLinearSystem(self, var, solver, boundaryConditions, dt)
#     155                                                            transientGeomCoeff=self._getTransientGeomCoeff(var),
#     156                                                            diffusionGeomCoeff=self._getDiffusionGeomCoeff(var),
# --> 157                                                            buildExplicitIfOther=self._buildExplcitIfOther)
#     158
#     159         self._buildCache(matrix, RHSvector)
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      66                                                                         transientGeomCoeff=transientGeomCoeff,
#      67                                                                         diffusionGeomCoeff=diffusionGeomCoeff,
# ---> 68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
#      70             matrix += tmpMatrix
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/terms/binaryTerm.pyc in _buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      68                                                                         buildExplicitIfOther=buildExplicitIfOther)
#      69
# ---> 70             matrix += tmpMatrix
#      71             RHSvector += tmpRHSvector
#      72
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/matrices/pysparseMatrix.pyc in __iadd__(self, other)
#      69
#      70     def __iadd__(self, other):
# ---> 71         self._iadd(self.matrix, other)
#      72         return self
#      73
#
# /Users/guyer/Documents/research/FiPy/fipy/fipy/matrices/pysparseMatrix.pyc in _iadd(self, L, other, sign)
#      74     def _iadd(self, L, other, sign = 1):
#      75         if other != 0:
# ---> 76             L.shift(sign, other.matrix)
#      77
#      78     def __add__(self, other):
#
# KeyboardInterrupt:

# %%
print min(eta[1]), min(eta[1]), eta[1].cellVolumeAverage
# Out:
# 2.61872505168e-168 2.61872505168e-168 2.90799688892e-165
